# %%
import numpy as np
import torch
from torchvision import transforms as T
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.optim as optim
from nltk.translate.bleu_score import corpus_bleu
import matplotlib.pyplot as plt

# %%
import os, sys
sys.path.append(os.path.dirname(sys.path[0]))

# %%
from model.encoder_perceiver import EncoderPerceiver
from model.encoder_cnn import EncoderResNet
from model.decoder import CaptioningTransformer
from utils.flickr8k_util import FlickrDataset, CapsCollate
from model.utils import show_image, decode_captions, strip_start_end
from experiment.solver import CaptioningSolver

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# load data
transform = T.Compose([
                T.Resize((224, 224)),
                T.ToTensor(),
                T.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)) # for flickr8k
            ])

# %%
base_dir = os.getcwd()[:-len("/notebook")]
data_location = base_dir + "/data/Flickr8k"

# %%
dataset =  FlickrDataset(
    root_dir = data_location + "/Images",
    caption_file = data_location + "/captions.txt",
    transform = transform,
    verbose = True )
# Out:
# building vocab
# buidling caption alias

# %%
caption_per_image = 5
num_data = len(dataset)
num_figures = num_data/caption_per_image
test_split = 0.2
val_split = 0.2
train_idx = int((1 - test_split - val_split) * num_figures)
train_abs_idx = train_idx * caption_per_image
val_idx = train_idx + int(val_split * num_figures)
val_abs_idx = val_idx * caption_per_image

# %%
train_abs_idx = 64
val_abs_idx = 64+32
train_indices = range(train_abs_idx)
val_indices = range(train_abs_idx, val_abs_idx)
test_indices = range(val_abs_idx, num_data)

# %%
# writing the dataloader
# setting the constants
BATCH_SIZE = 32
NUM_WORKER = 2

# token to represent the padding
pad_idx = dataset.vocab.stoi["<NULL>"]

loader_train = DataLoader(
    dataset=dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKER,
    sampler = sampler.SubsetRandomSampler(train_indices),
    collate_fn=CapsCollate(pad_idx=pad_idx,batch_first=True)
)

loader_val = DataLoader(
    dataset=dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKER,
    sampler = sampler.SubsetRandomSampler(val_indices),
    collate_fn=CapsCollate(pad_idx=pad_idx,batch_first=True)
)

loader_test = DataLoader(
    dataset=dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKER,
    sampler = sampler.SubsetRandomSampler(test_indices),
    collate_fn=CapsCollate(pad_idx=pad_idx,batch_first=True)
)

# %%
# create models
input_dim = 224 * 224
input_channels = 3
feature_dim = 512
word_emb_dim = 256
encoder = EncoderPerceiver(input_dim, input_channels = input_channels, 
                             num_iterations = 2, num_transformer_blocks = 4,
                             num_latents=32, latent_dim = feature_dim, 
                             cross_heads=4, cross_dim_head=16, 
                             latent_heads=4, latent_dim_head=16,
                             attn_dropout=0.5, ff_dropout=0.5)
decoder = CaptioningTransformer(dataset.vocab.stoi, input_dim=feature_dim, 
                                  wordvec_dim = word_emb_dim, max_length=50)

# %%
encoder_optimizer = optim.Adam(encoder.parameters(), 1e-3)
decoder_optimizer = optim.Adam(decoder.parameters(), 2e-3)

# %%
solver = CaptioningSolver(encoder, decoder, 
                          encoder_optimizer, decoder_optimizer,
                          dataset.vocab.itos, dataset.caption_alias, 
                          device = device, print_every = 100)

# %%
solver.train(loader_train, loader_val, num_epochs=50)
# Out:
# begin training epoch 1 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 1 of 50 epochs
# begin validation epoch 1 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 1 of 50 epochs
# begin training epoch 2 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 2 of 50 epochs
# begin validation epoch 2 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 2 of 50 epochs
# begin training epoch 3 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 3 of 50 epochs
# begin validation epoch 3 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 3 of 50 epochs
# begin training epoch 4 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 4 of 50 epochs
# begin validation epoch 4 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 4 of 50 epochs
# begin training epoch 5 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 5 of 50 epochs
# begin validation epoch 5 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 5 of 50 epochs
# begin training epoch 6 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 6 of 50 epochs
# begin validation epoch 6 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 6 of 50 epochs
# begin training epoch 7 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 7 of 50 epochs
# begin validation epoch 7 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 7 of 50 epochs
# begin training epoch 8 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 8 of 50 epochs
# begin validation epoch 8 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 8 of 50 epochs
# begin training epoch 9 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 9 of 50 epochs
# begin validation epoch 9 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 9 of 50 epochs
# begin training epoch 10 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 10 of 50 epochs
# begin validation epoch 10 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 10 of 50 epochs
# begin training epoch 11 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 11 of 50 epochs
# begin validation epoch 11 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 11 of 50 epochs
# begin training epoch 12 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 12 of 50 epochs
# begin validation epoch 12 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 12 of 50 epochs
# begin training epoch 13 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 13 of 50 epochs
# begin validation epoch 13 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 13 of 50 epochs
# begin training epoch 14 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 14 of 50 epochs
# begin validation epoch 14 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 14 of 50 epochs
# begin training epoch 15 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 15 of 50 epochs
# begin validation epoch 15 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 15 of 50 epochs
# begin training epoch 16 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 16 of 50 epochs
# begin validation epoch 16 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 16 of 50 epochs
# begin training epoch 17 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 17 of 50 epochs
# begin validation epoch 17 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 17 of 50 epochs
# begin training epoch 18 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 18 of 50 epochs
# begin validation epoch 18 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 18 of 50 epochs
# begin training epoch 19 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 19 of 50 epochs
# begin validation epoch 19 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 19 of 50 epochs
# begin training epoch 20 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 20 of 50 epochs
# begin validation epoch 20 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 20 of 50 epochs
# begin training epoch 21 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 21 of 50 epochs
# begin validation epoch 21 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 21 of 50 epochs
# begin training epoch 22 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 22 of 50 epochs
# begin validation epoch 22 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 22 of 50 epochs
# begin training epoch 23 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 23 of 50 epochs
# begin validation epoch 23 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 23 of 50 epochs
# begin training epoch 24 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 24 of 50 epochs
# begin validation epoch 24 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 24 of 50 epochs
# begin training epoch 25 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 25 of 50 epochs
# begin validation epoch 25 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 25 of 50 epochs
# begin training epoch 26 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 26 of 50 epochs
# begin validation epoch 26 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 26 of 50 epochs
# begin training epoch 27 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 27 of 50 epochs
# begin validation epoch 27 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 27 of 50 epochs
# begin training epoch 28 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 28 of 50 epochs
# begin validation epoch 28 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 28 of 50 epochs
# begin training epoch 29 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 29 of 50 epochs
# begin validation epoch 29 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 29 of 50 epochs
# begin training epoch 30 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 30 of 50 epochs
# begin validation epoch 30 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 30 of 50 epochs
# begin training epoch 31 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 31 of 50 epochs
# begin validation epoch 31 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 31 of 50 epochs
# begin training epoch 32 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 32 of 50 epochs
# begin validation epoch 32 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 32 of 50 epochs
# begin training epoch 33 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 33 of 50 epochs
# begin validation epoch 33 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 33 of 50 epochs
# begin training epoch 34 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 34 of 50 epochs
# begin validation epoch 34 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 34 of 50 epochs
# begin training epoch 35 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 35 of 50 epochs
# begin validation epoch 35 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 35 of 50 epochs
# begin training epoch 36 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 36 of 50 epochs
# begin validation epoch 36 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 36 of 50 epochs
# begin training epoch 37 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 37 of 50 epochs
# begin validation epoch 37 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 37 of 50 epochs
# begin training epoch 38 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 38 of 50 epochs
# begin validation epoch 38 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 38 of 50 epochs
# begin training epoch 39 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 39 of 50 epochs
# begin validation epoch 39 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 39 of 50 epochs
# begin training epoch 40 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 40 of 50 epochs
# begin validation epoch 40 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 40 of 50 epochs
# begin training epoch 41 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 41 of 50 epochs
# begin validation epoch 41 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 41 of 50 epochs
# begin training epoch 42 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 42 of 50 epochs
# begin validation epoch 42 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 42 of 50 epochs
# begin training epoch 43 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 43 of 50 epochs
# begin validation epoch 43 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 43 of 50 epochs
# begin training epoch 44 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 44 of 50 epochs
# begin validation epoch 44 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 44 of 50 epochs
# begin training epoch 45 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 45 of 50 epochs
# begin validation epoch 45 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 45 of 50 epochs
# begin training epoch 46 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 46 of 50 epochs
# begin validation epoch 46 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 46 of 50 epochs
# begin training epoch 47 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 47 of 50 epochs
# begin validation epoch 47 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 47 of 50 epochs
# begin training epoch 48 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 48 of 50 epochs
# begin validation epoch 48 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 48 of 50 epochs
# begin training epoch 49 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 49 of 50 epochs
# begin validation epoch 49 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 49 of 50 epochs
# begin training epoch 50 of 50 epochs
# training batch 0 of 2 batches
# computing BLEU score on training
# finish training epoch 50 of 50 epochs
# begin validation epoch 50 of 50 epochs
# validation batch 0 of 1 batches
# computing BLEU score on validation
# finish validation epoch 50 of 50 epochs

# %%
# visualize training
model_name = "perceiver_tiny2"
plt.plot(solver.train_loss_history)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.grid()
plt.title("Loss history during training on train set")
plt.savefig(base_dir + "/results/{}_train_loss.png".format(model_name), dpi=300, bbox_inches="tight")
plt.show()

plt.plot(solver.val_loss_history)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.grid()
plt.title("Loss history during training on validation set")
plt.savefig(base_dir + "/results/{}_val_loss.png".format(model_name), dpi=300, bbox_inches="tight")
plt.show()

plt.plot(solver.train_bleu)
plt.xlabel("epoch")
plt.ylabel("BLEU-4 score")
plt.grid()
plt.title("BLEU-4 score during training on training set")
plt.savefig(base_dir + "/results/{}_train_BLEU.png".format(model_name), dpi=300, bbox_inches="tight")
plt.show()

plt.plot(solver.val_bleu)
plt.xlabel("epoch")
plt.ylabel("BLEU-4 score")
plt.grid()
plt.title("BLEU-4 score during training on validation set")
plt.savefig(base_dir + "/results/{}_val_BLEU.png".format(model_name), dpi=300, bbox_inches="tight")
plt.show()

print("maximum BLEU-4 score on validation: ", np.max(solver.val_bleu))
# Out:
# maximum BLEU-4 score on validation:  0.46763837489181503

# %%
# inference

def inference(split_name, loader, filename=None):

    imgs, captions = next(iter(loader_train))
    img = imgs[0] # pick first image from the batch
    caption_vec = captions[0]
    ground_truth = decode_captions(caption_vec.detach().cpu().numpy(), dataset.vocab.itos)
    ground_truth = strip_start_end(ground_truth)
    feature = encoder(img.to(device=device, dtype=torch.float32).reshape(1, 3, 224, 224))
    caption_vec_pred = decoder.sample(feature, max_length=50, device=device)
    predict = decode_captions(caption_vec_pred, dataset.vocab.itos)[0]
    predict = strip_start_end(predict)

    title = "Split:{}\nGT:{}\nPredict:{}".format(split_name, ground_truth, predict)

    inp = img.numpy().transpose((1, 2, 0))
    plt.imshow(inp)
    plt.axis("off")
    plt.title(title)
    plt.savefig(base_dir+"/results/"+filename)
    plt.show()

# %%
# sample 5 images from train and val
for idx in range(5):
    split_name = "train"
    inference(split_name, loader_train, "{}_inf_{}_{}.png".format(model_name, split_name, idx))
    
for idx in range(5):
    split_name = "val"
    inference(split_name, loader_val, "{}_inf_{}_{}.png".format(model_name, split_name, idx))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# run on test, only run once!
#solver._val_step(loader_test)
#bleu_test = solver.val_bleu[-1]
#print("BLEU-4 Score on test set: ", bleu_test)
